# %% [markdown]
# # Python

# %% [markdown]
# ### Python Basics Questions

# %% [markdown]
# 1. What is Python, and why is it popular?
#
#   - Python a high-level, object-oriented and interpreted programming language which is used to build website and software. It is popular because of the following resons:-
#     a. It is most significant language for AI & ML.
#     b. It is easy to learn.
#     c. It can easily interact with other tools.
#     d. It has huge number of libraries(pre-written code).
#
# 2. What is an interpreter in Python?
#
#   - Interpretor is a program that reads and executes the python code line by line.
#
# 3. What are pre-defined keywords in Python?
#
#   - Pre-defined Keywords are reserved words in Python that have pre-defined meanings and cannot be used as identifiers like variable names or function name.
#
# 4. Can keywords be used as variable names?
#
#   - No keywords cannot be used as variable names
#
# 5. What is mutability in Python?
#
#   - Mutability  refers to the ability of an object to be modified after it is created. If the  object is mutable, its internal state can be changed such as adding, removing or updating element without creating a new object.
#
# 6. Why are lists mutable, but tuples are immutable?
#
#   - Lists are mutable as they can be modifies whereas the tuples doesnot allow any modification .
#
# 7. What is the difference between “==” and “is” operators in Python?
#
#   - In python "==" operator is used to compare values of two objects whereas the "is" operator is used as an identifier which checks if two variables refer to the same object in memory or not .
#
# 8. What are logical operators in Python?
#
#   - Logical operators are operators to evaluate a statement to return either a True or a False.
#
# 9. What is type casting in Python?
#
#   - Type casting  is a concept in programming where you change the data type of a variable from one type to another.
#
# 10. What is the difference between implicit and explicit type casting?
#
#   - Implicit type casting.
#
# a.The programming language automatically converts data from one type to another if needed.
#
# b. It saves time and effort because you don't have to manually convert data types.
#
# c. It happens automatically, reducing the chance of errors due to forgetting to convert types.
#
# d. Sometimes, when converting between data types, there can be a loss of precision.
#
#   - Explicit type casting
#
# a. In this type of casting the programmer explicitly instructs the compiler to convert a data type to another.
#
# b. It gives  the programmer more control over the conversion process, allowing for precise manipulation of data types.
#
# c. It can introduce complexity to the code, especially when dealing with multiple data type conversions.
#
# 11. What is the purpose of conditional statements in Python?
#
#   - A conditional statement is used to  determine the flow of code execution and its direction based on certain conditions.
#
# 12. How does the elif statement work?
#
#   - In elif condition if the first condition is false, it moves on to the next “elif” statement to check if that condition is true.
#
# ex.
# a = 30
# b = 31
# if b > a:
#   print("b is greater than a")
# elif a == b:
#   print("a is equal to b")
# else:
#   print("a is greater")
#
# 13. What is the difference between for and while loops?
#
#   - The for loops is best suited for the situations where you know exactly how many times the loop will execute whereas the while situations are dyanmic and are used where the iterations is unknown.
#
# 14. Describe a scenario where a while loop is more suitable than a for    loop?
#
#   - Imagine a situation where you are reading data from a file until you reach the end. You don't know how many lines the file contains, so you need a loop that keeps reading line by line until there are no more lines to read. In such a case, a "While Loop" is more appropriate because the number of iterations needed isn't known in advance,it depends on the file's content.
#
# # Practical Questions

# %% [markdown]
# 1. Write a Python program to print "Hello, World!"?
#
#   - print("Hello, World!")
#
# 2. Write a Python program that displays your name and age?
#
#   -  print("Name = Kanchan")
#      print("Age = 26")
#
# 3. Write code to print all the pre-defined keywords in Python using the keyword library?
#
#   -import keyword
#    print("the pre-defined keywords are:-")
#    print(keyword.kwlist)
#
# 4. Write a program that checks if a given word is a Python keyword?
#
#   - 4.import keyword
#       a = "await"
#
#       if keyword.iskeyword(a):
#       print("it is a keyword ")
#       else:
#       print("it is not a keyword")
#
# 5. Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
# for each?
#
#   - For list in python
#
#        b = [0, 1, 2, 3]
#        b[0] = 4
#        print(b)
#
#    - For Tuple in python
#
#        b = (0, 1, 2, 3)
#        b[0] = 4
#        print(b)
#
# 6. Write a function to demonstrate the behavior of mutable and immutable arguments?
#
#   - def modify_arguments(immutable, mutable):
#
#
#     print(f"Original immutable: {immutable} ")
#     print(f"Original mutable: {mutable}")
#
#     immutable = immutable
#     mutable.append(4)
#
#     print(f"Modified immutable: {immutable}, ")
#     print(f"Modified mutable: {mutable}, ")
#
#
# immutable_arg = 10
# mutable_arg = [1, 2, 3]
#
# modify_arguments(immutable_arg, mutable_arg)
#
# print(f"Outside function immutable: {immutable_arg}")
# print(f"Outside function mutable: {mutable_arg}")
#
# 7. Write a program that performs basic arithmetic operations on two user-input numbers?
#
#   - def arithmetic(num1, num2, operation):
#
#     if operation == '+':
#         return num1 + num2
#     elif operation == '-':
#         return num1 - num2
#     elif operation == '*':
#         return num1 * num2
#     elif operation == '/':
#         if num2 == 0:
#             print("Error: Cannot divide by zero.")
#             return None
#         else:
#             return num1 / num2
#     else:
#         print("Invalid operation. Please use +, -, *, or /.")
#         return None
#
#     num1 = float(input("Enter the first number: "))
#     num2 = float(input("Enter the second number: "))
#     operation = input("Enter the operation (+, -, *, /): ")
#
#     result = arithmetic(num1, num2, operation)
#
#     if result is not None:
#         print(f"The result is: {result}")
#
# except ValueError:
#     print("Invalid input. Please enter valid numbers.")
#
#
# 8. Write a program to demonstrate the use of logical operators?
#
#   - a = True
# b = False
# print("a and b:", a and b)
# print("a or b:", a or b)
#
# print("not a:", not a)
# print("not b:", not b)
# x = 5
# y = 10
# print("(x > 0) and (y < 15):", (x > 0) and (y < 15))
# print("(x < 0) or (y > 5):", (x < 0) or (y > 5))
# print("not (x == y):", not (x == y))
#
# 9. Write a Python program to convert user input from string to integer, float, and boolean types?
#
#   - def convert_input(input_string):
#     try:
#         integer_value = int(input_string)
#         print(f"Integer: {integer_value}")
#     except ValueError:
#         print("Not a valid integer.")
#
#     try:
#         float_value = float(input_string)
#         print(f"Float: {float_value}")
#     except ValueError:
#         print("Not a valid float.")
#
#     if input_string.lower() == "true":
#       bool_value = True
#       print(f"Boolean: {bool_value}")
#     elif input_string.lower() == "false":
#       bool_value = False
#       print(f"Boolean: {bool_value}")
#     else:
#       print("Not a valid boolean.")
#
# input_string = input("Enter a value: ")
# convert_input(input_string)
#
#
# 10. Write code to demonstrate type casting with list elements?
#
#   - my_list = ['1', '2', '3', '4', '5']
#
#
# int_list = [int(x) for x in my_list]
# print("List of integers:", int_list)
#
#
# float_list = [float(x) for x in int_list]
# print("List of floats:", float_list)
#
#
# str_list = [str(x) for x in float_list]
# print("List of strings:", str_list)
#
#
# mixed_list = [1, 2.0, '3', True]
#
#
# str_mixed_list = [str(x) for x in mixed_list]
# print("List of mixed types as strings:", str_mixed_list)
#
#
# 11. Write a program that checks if a number is positive, negative, or zero?
#
#   - num = float(input("Enter a number: "))
# if num > 0:
#    print("Positive number")
# elif num == 0:
#    print("Zero")
# else:
#    print("Negative number")
#
# 12. Write a for loop to print numbers from 1 to 10?
#
#   - for i in range(1, 11):
#     print(i)
#
# 13. Write a Python program to find the sum of all even numbers between 1 and 50?
#
#   - sum_of_even_numbers = 0
# for number in range(2, 51, 2):
#     sum_of_even_numbers += number
# print(sum_of_even_numbers)
#
#
# 14. Write a program to reverse a string using a while loop?
#
#   - def reverse_string(s):
#     reversed_s = ""
#     length = len(s) - 1
#     while length >= 0:
#         reversed_s += s[length]
#         length -= 1
#     return reversed_s
#
# input_string = "Hello, World!"
# reversed_string = reverse_string(input_string)
# print(f"Original string: {input_string}")
# print(f"Reversed string: {reversed_string}")
#
# 15. Write a Python program to calculate the factorial of a number provided by the user using a while loop?
#
#   - number = int("Enter a non-negative integer: ")
# factorial = 1
#
# if number < 0:
#     print("Factorial is not defined for negative numbers.")
# elif number == 0:
#     print("The factorial of 0 is 1")
# else:
#     while number > 0:
#         factorial *= number
#         number -= 1
#     print("The factorial is", factorial)
